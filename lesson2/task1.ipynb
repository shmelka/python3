# %% [markdown]
# ### 1) Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы) с сайта superjob.ru и hh.ru. Приложение должно анализировать несколько страниц сайта(также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
# *Наименование вакансии
# *Предлагаемую зарплату (отдельно мин. отдельно макс. и отдельно валюту)
# *Ссылку на саму вакансию
# *Сайт откуда собрана вакансия
#
# По своему желанию можно добавить еще работодателя и расположение. Данная структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas.

# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import re
import pandas as pd
from transliterate import translit

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
def parse_hh_compensation(value):
    min_com = None
    max_com = None
    cur = None
    if value:
        match = re.search(r'\b(руб|EUR|USD)\b', value)
        cur = match[0] if match else None
        
        match = re.search(r'\d*\s*\d*-\d*\s*\d*', value)
        if match:
            min_com = match[0].split('-')[0].replace('\xa0', '')
            max_com = match[0].split('-')[1].replace('\xa0', '')
            
        match = re.search(r'от\s\d*\s*\d*', value)
        if match:
            min_com = match[0].replace('\xa0', '').replace('от', '').replace(' ', '')
            
        match = re.search(r'до\s\d*\s*\d*', value)
        if match:
            max_com = match[0].replace('\xa0', '').replace('до', '').replace(' ', '')
    
    return {'min': min_com, 'max': max_com, 'cur': cur}

# %%
def hh_vacancy(query, page = 0):
    hh_link = 'https://hh.ru'
    params = {'st':'searchVacancy', 'text':query, 'page': page}
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
    html = requests.get(hh_link+'/search/vacancy', params=params, headers=headers).text
    soup = bs(html, 'lxml')
    vacancy_block = soup.find('div', {'class':'vacancy-serp'})
    if vacancy_block is None:
        return []
    vacancy_list = vacancy_block.findChildren('div', {'class':'vacancy-serp-item'}, recursive=False)
    
    items = []
    for item in vacancy_list:
        data = {}
        header = item.find('div', {'class':'vacancy-serp-item__row_header'})
        compensation = header.find('div', {'class':'vacancy-serp-item__sidebar'}).find('span', {'class':'bloko-section-header-3'})
        compensation = parse_hh_compensation(compensation.getText() if compensation else None)
        data['title'] = header.find('span', {'class':'g-user-content'}).getText()
        data['compensation_min'] = compensation['min']
        data['compensation_max'] = compensation['max']
        data['compensation_cur'] = compensation['cur']
        data['link'] = header.find('a')['href']
        data['site'] = hh_link
        items.append(data)
    return items

# %%
def superjob_vacancy(query, page = 1):
    trans_query = translit(query, "ru", reversed=True).lower()
    superjob_link = 'https://russia.superjob.ru'
    offset = page * 20
    limit = 20
    params = {'page': page}
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
    html = requests.get(superjob_link+'/vakansii/'+ trans_query +'.html', params=params, headers=headers).text
    soup = bs(html, 'lxml')
    vacancy_block = soup.find('div', {'class':'f-test-vacancy-item'})
    if vacancy_block is None:
        return []
    vacancy_block = vacancy_block.find_parent()
    vacancy_list = vacancy_block.findChildren('div', {'class':'f-test-vacancy-item'}, recursive=False)
    
    items = []
    for item in vacancy_list:
        data = {}        
        title = item.find('a').getText()        
        compensation = item.find('a').find_parent().find_next_sibling()
        compensation = parse_hh_compensation(compensation.getText())
        data['title'] = title
        data['compensation_min'] = compensation['min']
        data['compensation_max'] = compensation['max']
        data['compensation_cur'] = compensation['cur']
        data['link'] = superjob_link + item.find('a')['href']
        data['site'] = superjob_link
        items.append(data)
    return items

# %%
query = None
page = None
while(True):
    if query is None:
        query = input('Укажите вакансию для поиска: ')
    if page is None:
        page = 1
    else:
        page = int(input('Укажите страницу: '))
    items = hh_vacancy(query, page - 1) + superjob_vacancy(query, page)
    if len(items):
        vacancy = pd.DataFrame(data=items)
        print(vacancy)
    else:
        print('Вакансии не найдены или страницы не существует')
# Out:
# Укажите вакансию для поиска: программист
#                                                               title  \
# 0   Front-End Developer (Vue.js)
# 1   Developer Drupal / Программист Drupal
# 2   Ruby on Rails Developer
# 3   C# разработчик (начинающий, junior)
# 4   Developer Java / Программист Java (Spring Boot, VueJS)
# 5   Developer Java + Perl/ Программист Java + Perl
# 6   Backend разработчик (middle backend php developer)
# 7   Magento e-commerce lead developer / Ведущий программист Magento
# 8   Программист роботов
# 9   Java-разработчик на "Единый клиент"
# 10  PHP-программист
# 11  Программист Unity / Unity Developer
# 12  Unity C# Developer / Разработчик VR & AR
# 13  PHP-программист
# 14  Rust Developer
# 15  Разработчик Java
# 16  Tools Developer (C++, Unreal Engine)
# 17  Senior Full Stack Developer .NET
# 18  Программист Delphi + MS SQL
# 19  Senior Frontend Developer
# 20  Разработчик BI- систем
# 21  Senior WEB-Developer
# 22  .Net Developer
# 23  Senior Full Stack developer
# 24  PHP-программист
# 25  Инженер-программист 1С
# 26  Программист PHP
# 27  Программист разработчик (Unity3D/C# - мобильные приложения)
# 28  Front-end Developer (AngularJS)
# 29  Программист/web-разработчик (backend/frontend)
# 30  Программист 1С
# 31  Ведущий Java разработчик/ Архитектор Java
# 32  Software Developer (Floating License Server)
# 33  Salesforce Developer Middle/Senior
# 34  Программист-разработчик python (midle)
# 35  Middle/senior IOS-разработчик
# 36  Backend разработчик (PHP Developer)
# 37  Middle PHP Developer
# 38  Программист iOS (Swift)
# 39  Middle/Senior Java developer
# 40  Golang Developer
# 41  Fullstack Javascript Разработчик
# 42  Middle Java Developer
# 43  Server Developer (World of Tanks Blitz)
# 44  Node.JS Middle-Senior Backend developer
# 45  IOS разработчик
# 46  MIddle/senior android-разработчик
# 47  Game Logic Developer (World of Tanks)
# 48  Программист IT фармкомпанию
# 49  Senior Developer / IT Team Lead
# 50  Программист 1С 8 / Руководитель ИТ-проектов
# 51  Программист 1С
# 52  Инженер-программист
# 53  Программист C++
# 54  Программист 1С 8
# 55  Программист PHP Битрикс24
# 56  Программист ПЛК (инженер АСУТП)
# 57  Инженер-программист микроконтроллеров
# 58  Инженер-программист станков с ЧПУ
# 59  Программист Mac OS
# 60  Программист 1С
# 61  Инженер-программист
# 62  Программист C#
# 63  Web-программист / Web-разработчик
# 64  Программист 1С
# 65  Программист 1С (тестировщик)
# 66  Программист 1С
# 67  Инженер-программист
# 68  Java программист
# 69  Программист
#
#    compensation_min compensation_max compensation_cur  \
# 0   1500             None             EUR
# 1   2000             None             USD
# 2   2000             None             USD
# 3   100000           140000           руб
# 4   2000             None             USD
# 5   1700             None             USD
# 6   None             None             None
# 7   4000             None             USD
# 8   None             None             None
# 9   172000           230000           руб
# 10  None             None             None
# 11  None             None             None
# 12  130000           200000           руб
# 13  None             None             None
# 14  2000             None             EUR
# 15  None             140000           руб
# 16  None             None             None
# 17  None             250000           руб
# 18  80000            120000           руб
# 19  None             None             None
# 20  None             130000           руб
# 21  None             250000           руб
# 22  None             None             None
# 23  None             250000           руб
# 24  70000            120000           руб
# 25  None             None             None
# 26  70000            120000           руб
# 27  100000           None             руб
# 28  None             None             None
# 29  60000            100000           руб
# 30  3000             None             руб
# 31  None             None             None
# 32  None             None             None
# 33  None             None             None
# 34  None             180000           руб
# 35  400000           None             None
# 36  80000            200000           руб
# 37  None             None             None
# 38  80000            None             руб
# 39  None             None             None
# 40  None             None             None
# 41  1000             2000             USD
# 42  None             None             None
# 43  None             None             None
# 44  120000           260000           руб
# 45  180000           None             руб
# 46  400000           None             None
# 47  None             None             None
# 48  150000           None             None
# 49  2500             2800             USD
# 50  150000           None             руб
# 51  150000           None             руб
# 52  None             35000            руб
# 53  75000            None             руб
# 54  80000            None             руб
# 55  None             None             руб
# 56  71000            None             руб
# 57  None             None             None
# 58  None             None             None
# 59  None             None             None
# 60  None             None             None
# 61  60000            None             руб
# 62  130000           None             руб
# 63  None             None             руб
# 64  None             None             None
# 65  50000            None             руб
# 66  120000           None             руб
# 67  None             None             None
# 68  None             None             руб
# 69  17400            None             руб
#
#                                                                                                                 link  \
# 0   https://bezhetsk.hh.ru/vacancy/35590689?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 1   https://bezhetsk.hh.ru/vacancy/35850257?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 2   https://bezhetsk.hh.ru/vacancy/32954657?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 3   https://bezhetsk.hh.ru/vacancy/37022145?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 4   https://bezhetsk.hh.ru/vacancy/35849885?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 5   https://bezhetsk.hh.ru/vacancy/36680140?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 6   https://bezhetsk.hh.ru/vacancy/36528606?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 7   https://bezhetsk.hh.ru/vacancy/36871204?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 8   https://bezhetsk.hh.ru/vacancy/37053945?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 9   https://bezhetsk.hh.ru/vacancy/36975066?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 10  https://bezhetsk.hh.ru/vacancy/37042171?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 11  https://bezhetsk.hh.ru/vacancy/36725448?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 12  https://bezhetsk.hh.ru/vacancy/37008202?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 13  https://bezhetsk.hh.ru/vacancy/37017604?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 14  https://bezhetsk.hh.ru/vacancy/36357908?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 15  https://bezhetsk.hh.ru/vacancy/36634421?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 16  https://bezhetsk.hh.ru/vacancy/37048063?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 17  https://bezhetsk.hh.ru/vacancy/37036735?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 18  https://bezhetsk.hh.ru/vacancy/36988623?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 19  https://bezhetsk.hh.ru/vacancy/36528532?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 20  https://bezhetsk.hh.ru/vacancy/36632542?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 21  https://bezhetsk.hh.ru/vacancy/37036749?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 22  https://bezhetsk.hh.ru/vacancy/37031451?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 23  https://bezhetsk.hh.ru/vacancy/37036743?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 24  https://bezhetsk.hh.ru/vacancy/36961739?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 25  https://bezhetsk.hh.ru/vacancy/35409058?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 26  https://bezhetsk.hh.ru/vacancy/36975765?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 27  https://bezhetsk.hh.ru/vacancy/36611132?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 28  https://bezhetsk.hh.ru/vacancy/36724488?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 29  https://bezhetsk.hh.ru/vacancy/36996963?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 30  https://bezhetsk.hh.ru/vacancy/36987385?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 31  https://bezhetsk.hh.ru/vacancy/36841505?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 32  https://bezhetsk.hh.ru/vacancy/36864367?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 33  https://bezhetsk.hh.ru/vacancy/37034674?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 34  https://bezhetsk.hh.ru/vacancy/36955642?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 35  https://bezhetsk.hh.ru/vacancy/36925094?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 36  https://bezhetsk.hh.ru/vacancy/36953417?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 37  https://bezhetsk.hh.ru/vacancy/37029177?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 38  https://bezhetsk.hh.ru/vacancy/36949262?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 39  https://bezhetsk.hh.ru/vacancy/36191113?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 40  https://bezhetsk.hh.ru/vacancy/36814238?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 41  https://bezhetsk.hh.ru/vacancy/36964546?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 42  https://bezhetsk.hh.ru/vacancy/37031585?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 43  https://bezhetsk.hh.ru/vacancy/37029892?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 44  https://bezhetsk.hh.ru/vacancy/36768584?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 45  https://bezhetsk.hh.ru/vacancy/36802783?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 46  https://bezhetsk.hh.ru/vacancy/37010865?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 47  https://bezhetsk.hh.ru/vacancy/37029805?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 48  https://bezhetsk.hh.ru/vacancy/36995159?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 49  https://bezhetsk.hh.ru/vacancy/36948513?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 50  https://russia.superjob.ru/vakansii/programmist-1s-8-33585054.html
# 51  https://russia.superjob.ru/vakansii/programmist-1s-30603163.html
# 52  https://russia.superjob.ru/vakansii/inzhener-programmist-33484778.html
# 53  https://russia.superjob.ru/vakansii/programmist-c-33668690.html
# 54  https://russia.superjob.ru/vakansii/programmist-1s-8-33862097.html
# 55  https://russia.superjob.ru/vakansii/programmist-php-bitriks24-33849528.html
# 56  https://russia.superjob.ru/vakansii/programmist-plk-31627257.html
# 57  https://russia.superjob.ru/vakansii/inzhener-programmist-mikrokontrollerov-33861865.html
# 58  https://russia.superjob.ru/vakansii/inzhener-programmist-stankov-s-chpu-32268022.html
# 59  https://russia.superjob.ru/vakansii/programmist-mac-os-33778235.html
# 60  https://russia.superjob.ru/vakansii/programmist-1s-32020139.html
# 61  https://russia.superjob.ru/vakansii/inzhener-programmist-32592683.html
# 62  https://russia.superjob.ru/vakansii/programmist-c-33495380.html
# 63  https://russia.superjob.ru/vakansii/web-programmist-33861531.html
# 64  https://russia.superjob.ru/vakansii/programmist-1s-33679021.html
# 65  https://russia.superjob.ru/vakansii/programmist-1s-32017847.html
# 66  https://russia.superjob.ru/vakansii/programmist-1s-25466879.html
# 67  https://russia.superjob.ru/vakansii/inzhener-programmist-33805991.html
# 68  https://russia.superjob.ru/vakansii/java-programmist-33861560.html
# 69  https://russia.superjob.ru/vakansii/programmist-33824656.html
#
#                           site
# 0   https://hh.ru
# 1   https://hh.ru
# 2   https://hh.ru
# 3   https://hh.ru
# 4   https://hh.ru
# 5   https://hh.ru
# 6   https://hh.ru
# 7   https://hh.ru
# 8   https://hh.ru
# 9   https://hh.ru
# 10  https://hh.ru
# 11  https://hh.ru
# 12  https://hh.ru
# 13  https://hh.ru
# 14  https://hh.ru
# 15  https://hh.ru
# 16  https://hh.ru
# 17  https://hh.ru
# 18  https://hh.ru
# 19  https://hh.ru
# 20  https://hh.ru
# 21  https://hh.ru
# 22  https://hh.ru
# 23  https://hh.ru
# 24  https://hh.ru
# 25  https://hh.ru
# 26  https://hh.ru
# 27  https://hh.ru
# 28  https://hh.ru
# 29  https://hh.ru
# 30  https://hh.ru
# 31  https://hh.ru
# 32  https://hh.ru
# 33  https://hh.ru
# 34  https://hh.ru
# 35  https://hh.ru
# 36  https://hh.ru
# 37  https://hh.ru
# 38  https://hh.ru
# 39  https://hh.ru
# 40  https://hh.ru
# 41  https://hh.ru
# 42  https://hh.ru
# 43  https://hh.ru
# 44  https://hh.ru
# 45  https://hh.ru
# 46  https://hh.ru
# 47  https://hh.ru
# 48  https://hh.ru
# 49  https://hh.ru
# 50  https://russia.superjob.ru
# 51  https://russia.superjob.ru
# 52  https://russia.superjob.ru
# 53  https://russia.superjob.ru
# 54  https://russia.superjob.ru
# 55  https://russia.superjob.ru
# 56  https://russia.superjob.ru
# 57  https://russia.superjob.ru
# 58  https://russia.superjob.ru
# 59  https://russia.superjob.ru
# 60  https://russia.superjob.ru
# 61  https://russia.superjob.ru
# 62  https://russia.superjob.ru
# 63  https://russia.superjob.ru
# 64  https://russia.superjob.ru
# 65  https://russia.superjob.ru
# 66  https://russia.superjob.ru
# 67  https://russia.superjob.ru
# 68  https://russia.superjob.ru
# 69  https://russia.superjob.ru
# Укажите страницу: 4
#                                                title compensation_min  \
# 0   Начинающий Erlang/Elixir разработчик              100000
# 1   Программист 1C                                    120000
# 2   Embedded программист-разработчик                  100000
# 3   Программист- разработчик 1С                       130000
# 4   Программист Axapta                                150000
# 5   Программист Axapta                                150000
# 6   Программист                                       70000
# 7   PHP программист                                   1200
# 8   Инженер-программист АСУ ТП                        30000
# 9   Backend-разработчик                               90000
# 10  Программист (C, Linux)                            100000
# 11  Ведущий веб-разработчик                           200000
# 12  Начинающий Erlang/Elixir разработчик              100000
# 13  Программист-консультант 1C                        160000
# 14  Программист-разработчик 1С                        80000
# 15  Инженер-программист ПЛК                           None
# 16  Программист Python (разговорный английский)       100000
# 17  Backend Разработчик (PHP)                         80000
# 18  PHP-developer/PHP-программист                     140000
# 19  Web-программист                                   75000
# 20  Программист С++                                   100000
# 21  Программист MS SQL (Москва)                       90000
# 22  Программист 1С                                    110000
# 23  Web-разработчик                                   50000
# 24  Стажер – разработчик                              None
# 25  Python-разработчик                                100000
# 26  Backend-разработчик Node.js                       180000
# 27  Программист                                       None
# 28  Программист С#                                    None
# 29  Junior Программист C++ (3D/VR приложения)         50000
# 30  React Native Android iOS разработчик              160000
# 31  Программист 1C                                    100000
# 32  Python-разработчик                                100000
# 33  Инженер-программист АСУ ТП                        65000
# 34  Программист Front-end/JavaScript (Middle/Senior)  50000
# 35  C++ Developer / Программист С++                   80000
# 36  Программист .NET                                  80000
# 37  C# Middle Unity Developer                         60000
# 38  Javascript программист (Angular)                  70000
# 39  Frontend-разработчик (JavaScript, ReactJS)        90000
# 40  Senior PHP developer (Yii2)                       150000
# 41  Младший C#/SQL программист                        None
# 42  Программист Axapta (Ученик)                       40000
# 43  Программист 1C                                    60000
# 44  Middle Frontend Разработчик                       1700
# 45  Начинающий Erlang/Elixir разработчик              100000
# 46  Web-программист                                   100000
# 47  Ведущий инженер-программист АСУТП                 None
# 48  Бэкенд-разработчик (Ruby on Rails)                120000
# 49  Web-программист                                   None
# 50  Программист                                       None
# 51  Программист 1С                                    75000
# 52  Программист Битрикс 24                            None
# 53  Инженер-программист С/С++ / Инженер-схемотехник   None
# 54  Программист (Web-разработчик)                     None
# 55  PHP-программист (битрикс)                         90000
# 56  Программист 1С                                    45000
# 57  Инженер, схемотехник, программист                 None
# 58  Программист 1С                                    None
# 59  Инженер-программист станков с ЧПУ                 None
# 60  Php-разработчик, php-программист                  None
# 61  Программист 1С                                    None
# 62  Программист микроконтроллеров                     50000
# 63  Программист 1С                                    None
# 64  Программист 1С                                    90000
# 65  Инженер-программист                               None
# 66  Программист 1С                                    50000
# 67  Инженер-программист станков ЧПУ                   50000
# 68  Инженер-программист                               23700
# 69  Ведущий программист 1С                            None
#
#    compensation_max compensation_cur  \
# 0   None             руб
# 1   200000           руб
# 2   None             руб
# 3   None             руб
# 4   None             руб
# 5   None             руб
# 6   None             руб
# 7   2500             USD
# 8   55000            руб
# 9   None             руб
# 10  200000           руб
# 11  287500           руб
# 12  None             руб
# 13  None             руб
# 14  120000           руб
# 15  None             None
# 16  150000           руб
# 17  130000           руб
# 18  None             руб
# 19  None             руб
# 20  200000           руб
# 21  None             руб
# 22  140000           руб
# 23  110000           руб
# 24  None             None
# 25  None             руб
# 26  230000           руб
# 27  None             None
# 28  None             None
# 29  90000            руб
# 30  None             руб
# 31  130000           руб
# 32  None             руб
# 33  None             руб
# 34  150000           руб
# 35  150000           руб
# 36  120000           руб
# 37  100000           руб
# 38  100000           руб
# 39  None             руб
# 40  None             руб
# 41  None             None
# 42  None             руб
# 43  100000           руб
# 44  None             USD
# 45  None             руб
# 46  None             руб
# 47  120000           руб
# 48  None             руб
# 49  150000           руб
# 50  None             руб
# 51  None             руб
# 52  None             None
# 53  None             None
# 54  None             None
# 55  None             руб
# 56  None             руб
# 57  None             руб
# 58  50000            руб
# 59  None             None
# 60  None             None
# 61  None             None
# 62  None             руб
# 63  None             None
# 64  None             руб
# 65  None             None
# 66  None             руб
# 67  None             руб
# 68  None             руб
# 69  None             None
#
#                                                                                                                 link  \
# 0   https://bezhetsk.hh.ru/vacancy/33631780?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 1   https://bezhetsk.hh.ru/vacancy/36391192?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 2   https://bezhetsk.hh.ru/vacancy/36923736?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 3   https://bezhetsk.hh.ru/vacancy/37018405?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 4   https://bezhetsk.hh.ru/vacancy/35817865?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 5   https://bezhetsk.hh.ru/vacancy/35817866?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 6   https://bezhetsk.hh.ru/vacancy/36821860?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 7   https://bezhetsk.hh.ru/vacancy/35985712?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 8   https://bezhetsk.hh.ru/vacancy/36718631?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 9   https://bezhetsk.hh.ru/vacancy/35629745?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 10  https://bezhetsk.hh.ru/vacancy/36774067?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 11  https://bezhetsk.hh.ru/vacancy/33978956?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 12  https://bezhetsk.hh.ru/vacancy/33631776?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 13  https://bezhetsk.hh.ru/vacancy/36998377?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 14  https://bezhetsk.hh.ru/vacancy/35221842?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 15  https://bezhetsk.hh.ru/vacancy/36726858?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 16  https://bezhetsk.hh.ru/vacancy/36541868?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 17  https://bezhetsk.hh.ru/vacancy/36794172?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 18  https://bezhetsk.hh.ru/vacancy/35668633?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 19  https://bezhetsk.hh.ru/vacancy/36208050?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 20  https://bezhetsk.hh.ru/vacancy/36913436?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 21  https://bezhetsk.hh.ru/vacancy/36287249?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 22  https://bezhetsk.hh.ru/vacancy/36759756?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 23  https://bezhetsk.hh.ru/vacancy/36795524?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 24  https://bezhetsk.hh.ru/vacancy/34290624?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 25  https://bezhetsk.hh.ru/vacancy/36446006?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 26  https://bezhetsk.hh.ru/vacancy/36636237?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 27  https://bezhetsk.hh.ru/vacancy/26299449?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 28  https://bezhetsk.hh.ru/vacancy/36791498?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 29  https://bezhetsk.hh.ru/vacancy/36758764?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 30  https://bezhetsk.hh.ru/vacancy/36941565?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 31  https://bezhetsk.hh.ru/vacancy/36744180?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 32  https://bezhetsk.hh.ru/vacancy/36445975?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 33  https://bezhetsk.hh.ru/vacancy/37044313?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 34  https://bezhetsk.hh.ru/vacancy/37018894?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 35  https://bezhetsk.hh.ru/vacancy/36632113?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 36  https://bezhetsk.hh.ru/vacancy/36872013?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 37  https://bezhetsk.hh.ru/vacancy/36739613?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 38  https://bezhetsk.hh.ru/vacancy/36792325?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 39  https://bezhetsk.hh.ru/vacancy/36780348?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 40  https://bezhetsk.hh.ru/vacancy/36641820?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 41  https://bezhetsk.hh.ru/vacancy/36292549?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 42  https://bezhetsk.hh.ru/vacancy/36670568?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 43  https://bezhetsk.hh.ru/vacancy/36784112?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 44  https://bezhetsk.hh.ru/vacancy/36232473?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 45  https://bezhetsk.hh.ru/vacancy/33631777?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 46  https://bezhetsk.hh.ru/vacancy/36936176?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 47  https://bezhetsk.hh.ru/vacancy/34762568?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 48  https://bezhetsk.hh.ru/vacancy/31712815?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 49  https://bezhetsk.hh.ru/vacancy/36774284?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82
# 50  https://russia.superjob.ru/vakansii/programmist-33858285.html
# 51  https://russia.superjob.ru/vakansii/programmist-1s-33611337.html
# 52  https://russia.superjob.ru/vakansii/programmist-bitriks-24-33489025.html
# 53  https://russia.superjob.ru/vakansii/inzhener-programmist-s-30772757.html
# 54  https://russia.superjob.ru/vakansii/programmist-33737647.html
# 55  https://russia.superjob.ru/vakansii/php-programmist-33779960.html
# 56  https://russia.superjob.ru/vakansii/programmist-1s-25235840.html
# 57  https://russia.superjob.ru/vakansii/inzhener-32893242.html
# 58  https://russia.superjob.ru/vakansii/programmist-1s-33677865.html
# 59  https://russia.superjob.ru/vakansii/inzhener-programmist-stankov-s-chpu-27783541.html
# 60  https://russia.superjob.ru/vakansii/php-razrabotchik-33832041.html
# 61  https://russia.superjob.ru/vakansii/programmist-1s-30596524.html
# 62  https://russia.superjob.ru/vakansii/programmist-mikrokontrollerov-33783557.html
# 63  https://russia.superjob.ru/vakansii/programmist-1s-26924619.html
# 64  https://russia.superjob.ru/vakansii/programmist-1s-33687113.html
# 65  https://russia.superjob.ru/vakansii/inzhener-programmist-27257831.html
# 66  https://russia.superjob.ru/vakansii/programmist-1s-33803990.html
# 67  https://russia.superjob.ru/vakansii/inzhener-programmist-stankov-chpu-31287418.html
# 68  https://russia.superjob.ru/vakansii/inzhener-programmist-33729621.html
# 69  https://russia.superjob.ru/vakansii/veduschij-programmist-1s-31800604.html
#
#                           site
# 0   https://hh.ru
# 1   https://hh.ru
# 2   https://hh.ru
# 3   https://hh.ru
# 4   https://hh.ru
# 5   https://hh.ru
# 6   https://hh.ru
# 7   https://hh.ru
# 8   https://hh.ru
# 9   https://hh.ru
# 10  https://hh.ru
# 11  https://hh.ru
# 12  https://hh.ru
# 13  https://hh.ru
# 14  https://hh.ru
# 15  https://hh.ru
# 16  https://hh.ru
# 17  https://hh.ru
# 18  https://hh.ru
# 19  https://hh.ru
# 20  https://hh.ru
# 21  https://hh.ru
# 22  https://hh.ru
# 23  https://hh.ru
# 24  https://hh.ru
# 25  https://hh.ru
# 26  https://hh.ru
# 27  https://hh.ru
# 28  https://hh.ru
# 29  https://hh.ru
# 30  https://hh.ru
# 31  https://hh.ru
# 32  https://hh.ru
# 33  https://hh.ru
# 34  https://hh.ru
# 35  https://hh.ru
# 36  https://hh.ru
# 37  https://hh.ru
# 38  https://hh.ru
# 39  https://hh.ru
# 40  https://hh.ru
# 41  https://hh.ru
# 42  https://hh.ru
# 43  https://hh.ru
# 44  https://hh.ru
# 45  https://hh.ru
# 46  https://hh.ru
# 47  https://hh.ru
# 48  https://hh.ru
# 49  https://hh.ru
# 50  https://russia.superjob.ru
# 51  https://russia.superjob.ru
# 52  https://russia.superjob.ru
# 53  https://russia.superjob.ru
# 54  https://russia.superjob.ru
# 55  https://russia.superjob.ru
# 56  https://russia.superjob.ru
# 57  https://russia.superjob.ru
# 58  https://russia.superjob.ru
# 59  https://russia.superjob.ru
# 60  https://russia.superjob.ru
# 61  https://russia.superjob.ru
# 62  https://russia.superjob.ru
# 63  https://russia.superjob.ru
# 64  https://russia.superjob.ru
# 65  https://russia.superjob.ru
# 66  https://russia.superjob.ru
# 67  https://russia.superjob.ru
# 68  https://russia.superjob.ru
# 69  https://russia.superjob.ru
# Укажите страницу: 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~\Anaconda3\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     812         try:
# --> 813             msg_list = socket.recv_multipart(mode, copy=copy)
#     814         except zmq.ZMQError as e:
#
# ~\Anaconda3\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-be196a06b1a5> in <module>
#       7         page = 1
#       8     else:
# ----> 9         page = int(input('Укажите страницу: '))
#      10     items = hh_vacancy(query, page - 1) + superjob_vacancy(query, page)
#      11     if len(items):
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:
